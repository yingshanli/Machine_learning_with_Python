# %%
# 1. Load data

import pandas as pd

df = pd.read_csv('/Users/yingshanli/Library/Mobile Documents/com~apple~CloudDocs/Courses/CSCE878 intro ML/Recitation/OnlineNewsPopularity/OnlineNewsPopularity.csv')

# %%
# 2. Quick Check of the Data
df.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs   ...     \
# 0                   0.815385         4.0              2.0        1.0   ...
# 1                   0.791946         3.0              1.0        1.0   ...
# 2                   0.663866         3.0              1.0        1.0   ...
# 3                   0.665635         9.0              0.0        1.0   ...
# 4                   0.540890        19.0             19.0       20.0   ...
#
#     min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# 0                0.100000                     0.7               -0.350000
# 1                0.033333                     0.7               -0.118750
# 2                0.100000                     1.0               -0.466667
# 3                0.136364                     0.8               -0.369697
# 4                0.033333                     1.0               -0.220192
#
#     min_negative_polarity   max_negative_polarity   title_subjectivity  \
# 0                  -0.600               -0.200000             0.500000
# 1                  -0.125               -0.100000             0.000000
# 2                  -0.800               -0.133333             0.000000
# 3                  -0.600               -0.166667             0.000000
# 4                  -0.500               -0.050000             0.454545
#
#     title_sentiment_polarity   abs_title_subjectivity  \
# 0                  -0.187500                 0.000000
# 1                   0.000000                 0.500000
# 2                   0.000000                 0.500000
# 3                   0.000000                 0.500000
# 4                   0.136364                 0.045455
#
#     abs_title_sentiment_polarity   shares
# 0                       0.187500      593
# 1                       0.000000      711
# 2                       0.000000     1500
# 3                       0.000000     1200
# 4                       0.136364      505
#
# [5 rows x 61 columns]

# %%
# 3. Description of the Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
# url                               39644 non-null object
#  timedelta                        39644 non-null float64
#  n_tokens_title                   39644 non-null float64
#  n_tokens_content                 39644 non-null float64
#  n_unique_tokens                  39644 non-null float64
#  n_non_stop_words                 39644 non-null float64
#  n_non_stop_unique_tokens         39644 non-null float64
#  num_hrefs                        39644 non-null float64
#  num_self_hrefs                   39644 non-null float64
#  num_imgs                         39644 non-null float64
#  num_videos                       39644 non-null float64
#  average_token_length             39644 non-null float64
#  num_keywords                     39644 non-null float64
#  data_channel_is_lifestyle        39644 non-null float64
#  data_channel_is_entertainment    39644 non-null float64
#  data_channel_is_bus              39644 non-null float64
#  data_channel_is_socmed           39644 non-null float64
#  data_channel_is_tech             39644 non-null float64
#  data_channel_is_world            39644 non-null float64
#  kw_min_min                       39644 non-null float64
#  kw_max_min                       39644 non-null float64
#  kw_avg_min                       39644 non-null float64
#  kw_min_max                       39644 non-null float64
#  kw_max_max                       39644 non-null float64
#  kw_avg_max                       39644 non-null float64
#  kw_min_avg                       39644 non-null float64
#  kw_max_avg                       39644 non-null float64
#  kw_avg_avg                       39644 non-null float64
#  self_reference_min_shares        39644 non-null float64
#  self_reference_max_shares        39644 non-null float64
#  self_reference_avg_sharess       39644 non-null float64
#  weekday_is_monday                39644 non-null float64
#  weekday_is_tuesday               39644 non-null float64
#  weekday_is_wednesday             39644 non-null float64
#  weekday_is_thursday              39644 non-null float64
#  weekday_is_friday                39644 non-null float64
#  weekday_is_saturday              39644 non-null float64
#  weekday_is_sunday                39644 non-null float64
#  is_weekend                       39644 non-null float64
#  LDA_00                           39644 non-null float64
#  LDA_01                           39644 non-null float64
#  LDA_02                           39644 non-null float64
#  LDA_03                           39644 non-null float64
#  LDA_04                           39644 non-null float64
#  global_subjectivity              39644 non-null float64
#  global_sentiment_polarity        39644 non-null float64
#  global_rate_positive_words       39644 non-null float64
#  global_rate_negative_words       39644 non-null float64
#  rate_positive_words              39644 non-null float64
#  rate_negative_words              39644 non-null float64
#  avg_positive_polarity            39644 non-null float64
#  min_positive_polarity            39644 non-null float64
#  max_positive_polarity            39644 non-null float64
#  avg_negative_polarity            39644 non-null float64
#  min_negative_polarity            39644 non-null float64
#  max_negative_polarity            39644 non-null float64
#  title_subjectivity               39644 non-null float64
#  title_sentiment_polarity         39644 non-null float64
#  abs_title_subjectivity           39644 non-null float64
#  abs_title_sentiment_polarity     39644 non-null float64
#  shares                           39644 non-null int64
# dtypes: float64(59), int64(1), object(1)
# memory usage: 18.5+ MB

# %%
# 4. Dimension the Data

print("Dimension of the data: ", df.shape)

no_of_rows = df.shape[0]
no_of_columns = df.shape[1]

print("No. of Rows: %d" % no_of_rows)
print("No. of Columns: %d" % no_of_columns)
# Out:
# Dimension of the data:  (39644, 61)
# No. of Rows: 39644
# No. of Columns: 61

# %%
# 5. Visualization of Data
# Import Matplotlib for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

df.hist(bins=50, figsize=(40,40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115d0fcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dccb588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e19c860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e670828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1222fd588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1222fd5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f5e4438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122460278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x123913cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f075cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12394c2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12396e320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12388f390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12383a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12385ada0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1239a8e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1239d4e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123a00d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123a29550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123a54550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123a835c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123aaf630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123add630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123b0e0f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x123b47160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123b83160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123bbd160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123be4d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123c1eda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123c5ada0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123c91da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123c785c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x123cff940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123d3a8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123d748d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123daada0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123dcea58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123e0beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123e44eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123e79dd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x123e4ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123eec668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123f24668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123f60588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123f97ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123fca0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124007048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124034f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12406ff28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123fcaef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1240df6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124118748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124152668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12418c668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1241bf198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1241f95f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1242335f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12426b588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1242a1198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1242d7208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124313128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12434e128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124329940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1243afd68>]], dtype=object)

# %%
# 6. Visualize a Single Column
# %matplotlib inline
import matplotlib.pyplot as plt

df[' LDA_00'].hist(bins=50, figsize=(10,5))

# %%
# 7. Explore the Data 
# 7 (a). Explore the Data: Describe Numerical Attributes

df.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# min             0.000000                   0.000000      0.000000
# 25%             1.000000                   0.625739      4.000000
# 50%             1.000000                   0.690476      8.000000
# 75%             1.000000                   0.754630     14.000000
# max          1042.000000                 650.000000    304.000000
#
#         num_self_hrefs      num_imgs    num_videos      ...        \
# count     39644.000000  39644.000000  39644.000000      ...
# mean          3.293638      4.544143      1.249874      ...
# std           3.855141      8.309434      4.107855      ...
# min           0.000000      0.000000      0.000000      ...
# 25%           1.000000      1.000000      0.000000      ...
# 50%           3.000000      1.000000      0.000000      ...
# 75%           4.000000      4.000000      1.000000      ...
# max         116.000000    128.000000     91.000000      ...
#
#         min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# count            39644.000000            39644.000000            39644.000000
# mean                 0.095446                0.756728               -0.259524
# std                  0.071315                0.247786                0.127726
# min                  0.000000                0.000000               -1.000000
# 25%                  0.050000                0.600000               -0.328383
# 50%                  0.100000                0.800000               -0.253333
# 75%                  0.100000                1.000000               -0.186905
# max                  1.000000                1.000000                0.000000
#
#         min_negative_polarity   max_negative_polarity   title_subjectivity  \
# count            39644.000000            39644.000000         39644.000000
# mean                -0.521944               -0.107500             0.282353
# std                  0.290290                0.095373             0.324247
# min                 -1.000000               -1.000000             0.000000
# 25%                 -0.700000               -0.125000             0.000000
# 50%                 -0.500000               -0.100000             0.150000
# 75%                 -0.300000               -0.050000             0.500000
# max                  0.000000                0.000000             1.000000
#
#         title_sentiment_polarity   abs_title_subjectivity  \
# count               39644.000000             39644.000000
# mean                    0.071425                 0.341843
# std                     0.265450                 0.188791
# min                    -1.000000                 0.000000
# 25%                     0.000000                 0.166667
# 50%                     0.000000                 0.500000
# 75%                     0.150000                 0.500000
# max                     1.000000                 0.500000
#
#         abs_title_sentiment_polarity         shares
# count                   39644.000000   39644.000000
# mean                        0.156064    3395.380184
# std                         0.226294   11626.950749
# min                         0.000000       1.000000
# 25%                         0.000000     946.000000
# 50%                         0.000000    1400.000000
# 75%                         0.250000    2800.000000
# max                         1.000000  843300.000000
#
# [8 rows x 60 columns]

# %%
# 7(b). Describe Columns with Categorical Attributes
# Value Counts for Categorical Columns

# Print the value counts for categorical columns
# df[df.columns[2:4]] 
for col in df.loc[:, ' timedelta':' n_unique_tokens']:
        print('\nColumn Name:', col,)
        print(df[col].value_counts())
# Out:
# Column Name:  timedelta
# 91.0     104
# 72.0     102
# 84.0     101
# 59.0      99
# 29.0      99
# 210.0     97
# 182.0     96
# 28.0      95
# 37.0      95
# 127.0     94
# 161.0     94
# 52.0      94
# 77.0      93
# 79.0      93
# 35.0      93
# 23.0      93
# 100.0     92
# 36.0      92
# 66.0      92
# 92.0      92
# 71.0      91
# 49.0      90
# 135.0     90
# 169.0     90
# 126.0     90
# 121.0     90
# 260.0     89
# 64.0      89
# 50.0      89
# 729.0     89
#         ...
# 522.0     19
# 481.0     19
# 256.0     19
# 243.0     19
# 145.0     19
# 495.0     19
# 432.0     19
# 677.0     19
# 264.0     19
# 383.0     19
# 557.0     19
# 621.0     19
# 691.0     18
# 404.0     18
# 299.0     18
# 508.0     18
# 494.0     18
# 684.0     18
# 585.0     18
# 705.0     17
# 719.0     17
# 571.0     17
# 369.0     17
# 635.0     16
# 291.0     16
# 375.0     15
# 656.0     15
# 376.0     15
# 730.0     12
# 8.0        8
# Name:  timedelta, Length: 724, dtype: int64
#
# Column Name:  n_tokens_title
# 10.0    7358
# 11.0    6960
# 9.0     6278
# 12.0    5299
# 8.0     4227
# 13.0    3509
# 7.0     2120
# 14.0    1733
# 6.0      805
# 15.0     756
# 16.0     259
# 5.0      184
# 17.0      91
# 4.0       28
# 18.0      22
# 19.0       6
# 3.0        5
# 20.0       2
# 2.0        1
# 23.0       1
# Name:  n_tokens_title, dtype: int64
#
# Column Name:  n_tokens_content
# 0.0       1181
# 286.0      101
# 335.0       86
# 225.0       86
# 279.0       85
# 242.0       84
# 301.0       82
# 246.0       80
# 258.0       80
# 232.0       80
# 294.0       80
# 318.0       79
# 256.0       79
# 197.0       79
# 230.0       78
# 292.0       78
# 209.0       78
# 315.0       78
# 276.0       78
# 281.0       78
# 317.0       78
# 303.0       77
# 223.0       76
# 263.0       76
# 299.0       76
# 235.0       76
# 190.0       76
# 327.0       75
# 240.0       75
# 184.0       75
#           ...
# 2718.0       1
# 3076.0       1
# 1775.0       1
# 1842.0       1
# 3774.0       1
# 2305.0       1
# 2844.0       1
# 3113.0       1
# 2635.0       1
# 2328.0       1
# 7002.0       1
# 1989.0       1
# 1888.0       1
# 2578.0       1
# 1919.0       1
# 2249.0       1
# 1923.0       1
# 3309.0       1
# 1268.0       1
# 3751.0       1
# 2170.0       1
# 2636.0       1
# 2662.0       1
# 2016.0       1
# 1944.0       1
# 2936.0       1
# 1892.0       1
# 1819.0       1
# 2651.0       1
# 3086.0       1
# Name:  n_tokens_content, Length: 2406, dtype: int64
#
# Column Name:  n_unique_tokens
# 0.000000    1181
# 0.666667      10
# 0.552083       9
# 0.740157       8
# 0.642512       8
# 0.640394       8
# 0.656977       8
# 0.649746       8
# 0.653846       8
# 0.674757       8
# 0.648780       8
# 0.613475       8
# 0.694805       8
# 0.618110       8
# 0.623529       8
# 0.636364       8
# 0.727941       7
# 0.601695       7
# 0.571429       7
# 0.651429       7
# 0.618123       7
# 0.647059       7
# 0.643519       7
# 0.621399       7
# 0.715447       7
# 0.565543       7
# 0.666667       7
# 0.685185       7
# 0.697987       7
# 0.602459       7
#             ...
# 0.558376       1
# 0.538860       1
# 0.576826       1
# 0.448224       1
# 0.730964       1
# 0.475738       1
# 0.493827       1
# 0.545272       1
# 0.510092       1
# 0.496523       1
# 0.449883       1
# 0.443539       1
# 0.416159       1
# 0.541401       1
# 0.536585       1
# 0.518883       1
# 0.444097       1
# 0.495633       1
# 0.346310       1
# 0.650442       1
# 0.518724       1
# 0.485616       1
# 0.506390       1
# 0.520309       1
# 0.494215       1
# 0.370855       1
# 0.535179       1
# 0.472340       1
# 0.535714       1
# 0.464286       1
# Name:  n_unique_tokens, Length: 27281, dtype: int64

# %%
# 7(c). Explore the Data: Explore Columns
df[' LDA_03']
# Out:
# 0        0.041263
# 1        0.050101
# 2        0.033334
# 3        0.028905
# 4        0.028572
# 5        0.022224
# 6        0.020015
# 7        0.022224
# 8        0.029696
# 9        0.040001
# 10       0.261864
# 11       0.028715
# 12       0.304298
# 13       0.866499
# 14       0.885144
# 15       0.033335
# 16       0.839742
# 17       0.033333
# 18       0.033403
# 19       0.025000
# 20       0.020008
# 21       0.028574
# 22       0.028574
# 23       0.200011
# 24       0.050000
# 25       0.020004
# 26       0.132969
# 27       0.022349
# 28       0.020008
# 29       0.033336
#            ...
# 39614    0.028571
# 39615    0.440050
# 39616    0.866389
# 39617    0.723872
# 39618    0.022223
# 39619    0.020001
# 39620    0.022225
# 39621    0.733264
# 39622    0.022223
# 39623    0.025002
# 39624    0.028572
# 39625    0.118088
# 39626    0.040000
# 39627    0.033335
# 39628    0.040000
# 39629    0.839096
# 39630    0.020410
# 39631    0.040000
# 39632    0.028571
# 39633    0.033334
# 39634    0.802630
# 39635    0.033372
# 39636    0.354187
# 39637    0.155574
# 39638    0.033335
# 39639    0.025000
# 39640    0.681635
# 39641    0.643794
# 39642    0.040002
# 39643    0.050659
# Name:  LDA_03, Length: 39644, dtype: float64

# %%
# 7(d). Check the Invalid (zero) Values in a Column
# Write a function to count 0s in a given column

count = 0

def zeroCount(dataFrame, columnName):
    noOfZeros = 0
    for i in range(dataFrame.shape[0]):
        if dataFrame[columnName][i] == 0:
            noOfZeros = noOfZeros + 1
    return noOfZeros

count = zeroCount(df, ' LDA_03')

print("Number of 0s in the Target Column: %d" % count)
# Out:
# Number of 0s in the Target Column: 1

# %%
# 8. Data cleanning

df = df[~df[' num_videos'].isin([0, 1])]

# %%
# 9. Explore the Target column (after removing the 0 entries)
df[' num_videos']
# Out:
# 13       21.0
# 47        6.0
# 99       11.0
# 126      11.0
# 129       3.0
# 181      16.0
# 190      21.0
# 195       3.0
# 206      21.0
# 222       3.0
# 232      11.0
# 238      11.0
# 253      21.0
# 261      12.0
# 264      21.0
# 284       7.0
# 292      11.0
# 304      11.0
# 310      10.0
# 338       2.0
# 339       2.0
# 342      10.0
# 400      10.0
# 409      21.0
# 424       2.0
# 428      12.0
# 437      26.0
# 446       2.0
# 487       9.0
# 495       2.0
#          ...
# 39176     3.0
# 39186     2.0
# 39213     2.0
# 39236     2.0
# 39238    14.0
# 39247     5.0
# 39256     3.0
# 39262     3.0
# 39286     3.0
# 39313     2.0
# 39343     3.0
# 39361     5.0
# 39375    20.0
# 39379     2.0
# 39389    12.0
# 39392     3.0
# 39445     7.0
# 39490     2.0
# 39491     8.0
# 39498     3.0
# 39524     5.0
# 39529    12.0
# 39536     2.0
# 39556    10.0
# 39575     6.0
# 39600     8.0
# 39629     2.0
# 39634     2.0
# 39640    48.0
# 39643     2.0
# Name:  num_videos, Length: 5135, dtype: float64

# %%
# 10. Count the Number of 0s in the Target column (after removing the 0 entries)
newCount = 0

def zeroCount(dataFrame, columnName):
    noOfZeros = 0
    for i in range(len(dataFrame.index.get_values())):
        if dataFrame[columnName][dataFrame.index.get_values()[i]] == 0:
            noOfZeros = noOfZeros + 1
    return noOfZeros

newCount = zeroCount(df, ' LDA_03')

print("Number of 0s in the Target Column: %d" % newCount)
# Out:
# Number of 0s in the Target Column: 0

# %%
# 11. Rename a Column
df = df.rename(columns={' weekday_is_monday': 'Monday'})

df.head()
# Out:
#                                                    url   timedelta  \
# 13           http://mashable.com/2013/01/07/dad-jokes/       731.0
# 47   http://mashable.com/2013/01/07/one-directions-...       731.0
# 99   http://mashable.com/2013/01/09/blue-umbrella-t...       729.0
# 126       http://mashable.com/2013/01/09/gopro-videos/       729.0
# 129  http://mashable.com/2013/01/09/hobbit-misty-mo...       729.0
#
#       n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 13               9.0              285.0          0.744186                1.0
# 47              12.0              161.0          0.668831                1.0
# 99               7.0              376.0          0.569014                1.0
# 126              8.0              270.0          0.600775                1.0
# 129             10.0              254.0          0.627530                1.0
#
#       n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  \
# 13                    0.841530         4.0              2.0        0.0
# 47                    0.752381         5.0              4.0        0.0
# 99                    0.686695         3.0              2.0        0.0
# 126                   0.740741         5.0              4.0        1.0
# 129                   0.697143         5.0              1.0        0.0
#
#       ...      min_positive_polarity   max_positive_polarity  \
# 13    ...                       0.16                    1.00
# 47    ...                       0.10                    0.85
# 99    ...                       0.10                    0.80
# 126   ...                       0.10                    1.00
# 129   ...                       0.10                    1.00
#
#       avg_negative_polarity   min_negative_polarity   max_negative_polarity  \
# 13                -0.337889                    -0.7               -0.100000
# 47                -0.363889                    -0.8               -0.125000
# 99                -0.283333                    -0.4               -0.166667
# 126               -0.408333                    -0.6               -0.125000
# 129               -0.283333                    -0.4               -0.166667
#
#       title_subjectivity   title_sentiment_polarity   abs_title_subjectivity  \
# 13              1.000000                      -1.00                 0.500000
# 47              0.583333                       0.25                 0.083333
# 99              0.100000                       0.00                 0.400000
# 126             0.900000                      -0.60                 0.400000
# 129             0.600000                       0.50                 0.100000
#
#       abs_title_sentiment_polarity   shares
# 13                            1.00    10000
# 47                            0.25     1200
# 99                            0.00     1900
# 126                           0.60     1700
# 129                           0.50    19400
#
# [5 rows x 61 columns]

# %%
# 12(a). Explore The Target Column: Get the Column Statistics

# Distribution of Grades

df['Monday'].describe()
# Out:
# count    5135.000000
# mean        0.166699
# std         0.372743
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Monday, dtype: float64

# %%
# 12(b). Explore The Target Column: Get the Column Value_Counts
df['Monday'].value_counts()
# Out:
# 0.0    4279
# 1.0     856
# Name: Monday, dtype: int64

# %%
# 12(c). Explore The Target Column: Plot The Distribution of the Labels

# Import Matplotlib for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = (15, 15)

# Bar plot of grades
plt.bar(df[' num_videos'].value_counts().index, 
        df[' num_videos'].value_counts().values,
         fill = 'navy', edgecolor = 'k', width = 1)
plt.xlabel('Grade'); 
plt.ylabel('Count'); 
plt.title('Distribution of Final Grades');
plt.xticks(list(range(0, 40, 5)));

# %%
# 13. Calculate & Plot Percentile for Grades

# Scipy helper functions
from scipy.stats import percentileofscore


# Calculate percentile for grades
df['percentile'] = df[' num_videos'].apply(lambda x: percentileofscore(df[' num_videos'], x))

# Plot percentiles for grades
plt.figure(figsize = (10, 6))

plt.plot(df[' num_videos'], df['percentile'], 'o')

plt.xticks(range(0, 100, 10), range(0, 100, 10))

plt.xlabel('Score'); 
plt.ylabel('Percentile'); 
plt.title('num_videos Percentiles');

# %%
# 14. Looking for Numerical Correlations with the Target Column

# Variable Correlations with Final Grade

df.corr()[' num_videos'].sort_values(ascending=False)
# Out:
#  num_videos                       1.000000
# percentile                        0.822757
#  global_rate_negative_words       0.314740
#  LDA_03                           0.303535
#  max_positive_polarity            0.275394
#  num_hrefs                        0.258920
#  timedelta                        0.205774
#  avg_positive_polarity            0.194730
#  n_tokens_content                 0.187647
#  kw_min_min                       0.176688
#  num_self_hrefs                   0.158370
#  rate_negative_words              0.156578
#  global_rate_positive_words       0.132161
#  global_subjectivity              0.126982
#  data_channel_is_entertainment    0.119452
#  self_reference_max_shares        0.112751
#  max_negative_polarity            0.106787
#  kw_avg_max                       0.100846
#  kw_avg_avg                       0.090483
#  title_subjectivity               0.081416
#  abs_title_sentiment_polarity     0.068681
#  kw_min_avg                       0.061053
#  kw_min_max                       0.060632
#  self_reference_avg_sharess       0.053960
#  n_non_stop_words                 0.048851
#  average_token_length             0.047872
#  title_sentiment_polarity         0.037753
# Monday                            0.034017
#  kw_max_avg                       0.029990
#  kw_avg_min                       0.015707
#                                     ...
#  kw_max_min                       0.008842
#  weekday_is_wednesday             0.003448
#  weekday_is_saturday              0.002225
#  weekday_is_friday                0.000020
#  shares                          -0.002246
#  weekday_is_thursday             -0.002716
#  weekday_is_tuesday              -0.004549
#  data_channel_is_bus             -0.008396
#  self_reference_min_shares       -0.013856
#  LDA_00                          -0.026019
#  n_unique_tokens                 -0.031825
#  LDA_01                          -0.031975
#  is_weekend                      -0.033670
#  abs_title_subjectivity          -0.039094
#  data_channel_is_socmed          -0.039819
#  weekday_is_sunday               -0.046106
#  data_channel_is_lifestyle       -0.053118
#  n_non_stop_unique_tokens        -0.062055
#  min_positive_polarity           -0.067262
#  global_sentiment_polarity       -0.076623
#  num_keywords                    -0.102890
#  rate_positive_words             -0.115160
#  num_imgs                        -0.129200
#  data_channel_is_tech            -0.151971
#  kw_max_max                      -0.168900
#  avg_negative_polarity           -0.187456
#  LDA_02                          -0.189055
#  LDA_04                          -0.195500
#  data_channel_is_world           -0.199674
#  min_negative_polarity           -0.250787
# Name:  num_videos, Length: 61, dtype: float64

# %%
# 15. Visualizing the Numerical Correlations

from pandas.tools.plotting import scatter_matrix


attributes = [" num_videos", " LDA_02", " LDA_04", " num_imgs"]

scatter_matrix(df[attributes], figsize=(15, 12))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115f916d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cf4cfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d2d0fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d31e080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d357160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d357198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d3bb8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d3f1860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d42d860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d3c3940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d49b160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d4d3630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d50cb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d5349e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d571be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d5a8f60>]], dtype=object)

# %%
# 16. Visualizing Numerical Correlation Between Two Attributes

df.plot(title="Scatter Plot", kind="scatter", x=" num_imgs", y=" num_videos")

# %%
# 17. Categorical Correlations using One-Hot Encoding

df[' is_weekend'] = df[' is_weekend'].apply(lambda x: str(x))
df[' weekday_is_tuesday'] = df[' weekday_is_tuesday'].apply(lambda x: str(x))
df[' weekday_is_friday'] = df[' weekday_is_friday'].apply(lambda x: str(x))

    
# Select only categorical variables
category_df = df.select_dtypes('object')

category_df = category_df.drop('url', axis =1)

# One hot encode the variables
dummy_df = pd.get_dummies(category_df)

# Put the grade back in the dataframe
dummy_df[' num_videos'] = df[' num_videos']

dummy_df.head()
# Out:
#       weekday_is_tuesday_0.0   weekday_is_tuesday_1.0   weekday_is_friday_0.0  \
# 13                         1                        0                       1
# 47                         1                        0                       1
# 99                         1                        0                       1
# 126                        1                        0                       1
# 129                        1                        0                       1
#
#       weekday_is_friday_1.0   is_weekend_0.0   is_weekend_1.0   num_videos
# 13                        0                1                0         21.0
# 47                        0                1                0          6.0
# 99                        0                1                0         11.0
# 126                       0                1                0         11.0
# 129                       0                1                0          3.0

# %%
# 18. Looking for Categorical Correlations with the Target Column

# Correlations in one-hot encoded dataframe
dummy_df.corr()[' num_videos'].sort_values(ascending=False)
# Out:
#  num_videos                1.000000
#  is_weekend_0.0            0.033670
#  weekday_is_tuesday_0.0    0.004549
#  weekday_is_friday_1.0     0.000020
#  weekday_is_friday_0.0    -0.000020
#  weekday_is_tuesday_1.0   -0.004549
#  is_weekend_1.0           -0.033670
# Name:  num_videos, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5135 entries, 13 to 39643
# Data columns (total 60 columns):
# url                               5135 non-null object
#  timedelta                        5135 non-null float64
#  n_tokens_title                   5135 non-null float64
#  n_tokens_content                 5135 non-null float64
#  n_unique_tokens                  5135 non-null float64
#  n_non_stop_words                 5135 non-null float64
#  n_non_stop_unique_tokens         5135 non-null float64
#  num_hrefs                        5135 non-null float64
#  num_self_hrefs                   5135 non-null float64
#  num_imgs                         5135 non-null float64
#  num_videos                       5135 non-null float64
#  average_token_length             5135 non-null float64
#  num_keywords                     5135 non-null float64
#  data_channel_is_lifestyle        5135 non-null float64
#  data_channel_is_entertainment    5135 non-null float64
#  data_channel_is_bus              5135 non-null float64
#  data_channel_is_socmed           5135 non-null float64
#  data_channel_is_tech             5135 non-null float64
#  data_channel_is_world            5135 non-null float64
#  kw_min_min                       5135 non-null float64
#  kw_max_min                       5135 non-null float64
#  kw_avg_min                       5135 non-null float64
#  kw_min_max                       5135 non-null float64
#  kw_max_max                       5135 non-null float64
#  kw_avg_max                       5135 non-null float64
#  kw_min_avg                       5135 non-null float64
#  kw_max_avg                       5135 non-null float64
#  kw_avg_avg                       5135 non-null float64
#  self_reference_min_shares        5135 non-null float64
#  self_reference_max_shares        5135 non-null float64
#  self_reference_avg_sharess       5135 non-null float64
# Monday                            5135 non-null float64
#  weekday_is_wednesday             5135 non-null float64
#  weekday_is_thursday              5135 non-null float64
#  weekday_is_saturday              5135 non-null float64
#  weekday_is_sunday                5135 non-null float64
#  is_weekend                       5135 non-null object
#  LDA_00                           5135 non-null float64
#  LDA_01                           5135 non-null float64
#  LDA_02                           5135 non-null float64
#  LDA_03                           5135 non-null float64
#  LDA_04                           5135 non-null float64
#  global_subjectivity              5135 non-null float64
#  global_sentiment_polarity        5135 non-null float64
#  global_rate_positive_words       5135 non-null float64
#  global_rate_negative_words       5135 non-null float64
#  rate_positive_words              5135 non-null float64
#  rate_negative_words              5135 non-null float64
#  avg_positive_polarity            5135 non-null float64
#  min_positive_polarity            5135 non-null float64
#  max_positive_polarity            5135 non-null float64
#  avg_negative_polarity            5135 non-null float64
#  min_negative_polarity            5135 non-null float64
#  max_negative_polarity            5135 non-null float64
#  title_subjectivity               5135 non-null float64
#  title_sentiment_polarity         5135 non-null float64
#  abs_title_subjectivity           5135 non-null float64
#  abs_title_sentiment_polarity     5135 non-null float64
#  shares                           5135 non-null int64
# percentile                        5135 non-null float64
# dtypes: float64(57), int64(1), object(2)
# memory usage: 2.4+ MB

# %%
# 18(a). Generating an Effective Feature Set: Drop Redundant & Meaningless Features

# Drop the school and the grades from features
df = df.drop(columns=[' weekday_is_wednesday', ' weekday_is_saturday'])

# %%
# 18(b). Generating an Effective Feature Set: Select a Set of Features

# Combine the one-hot coded categorical features with the numerical features
df = pd.get_dummies(df)

# Find correlations with the Grade
# Note that we have considered the absolute values of the correlations
# This will help to identify the most correlated features 
most_correlated = df.corr().abs()[' num_keywords'].sort_values(ascending=False)

# Maintain the top 7 most correlation features with Grade
most_correlated = most_correlated[:8]

print("Most Correlated Features:\n")
print(most_correlated)
# Out:
# Most Correlated Features:
#
#  num_keywords                  1.000000
#  kw_min_max                    0.284469
#  kw_avg_max                    0.262798
#  kw_min_avg                    0.256825
#  LDA_04                        0.180105
#  data_channel_is_tech          0.152898
#  global_rate_negative_words    0.147490
#  kw_max_avg                    0.125142
# Name:  num_keywords, dtype: float64

# %%
# 19. Edit the DataFrame to Contain Only the Most Correlated Features

# See the most correlated column names
print("Most Correlated Index: ", most_correlated.index)

# Edit the DataFrame to Contain Only the Most Correlated Features¶
df = df.ix[:, most_correlated.index]
df = df.drop(columns = ' kw_min_max') # This feature has the same correlation as schoolsup_yes


df.head()
# Out:
# Most Correlated Index:  Index([' num_keywords', ' kw_min_max', ' kw_avg_max', ' kw_min_avg', ' LDA_04',
#        ' data_channel_is_tech', ' global_rate_negative_words', ' kw_max_avg'],
#       dtype='object')
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   import sys
#       num_keywords   kw_avg_max   kw_min_avg    LDA_04   data_channel_is_tech  \
# 13             6.0     0.000000          0.0  0.033337                    0.0
# 47            10.0     0.000000          0.0  0.020005                    0.0
# 99             9.0  4055.555556          0.0  0.022226                    0.0
# 126           10.0  7269.000000          0.0  0.143039                    0.0
# 129           10.0  4110.000000          0.0  0.020000                    0.0
#
#       global_rate_negative_words    kw_max_avg
# 13                      0.052632      0.000000
# 47                      0.018634      0.000000
# 99                      0.005319   5428.571429
# 126                     0.011111  11800.000000
# 129                     0.007874   8566.666667

# %%
# 20. Generate Pairs Plot of Selected Variables

# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
from scipy import stats

# Calculate correlation coefficient
def corrfunc(x, y, **kws):
    r, _ = stats.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.1, .6), xycoords=ax.transAxes,
               size = 24)
    
cmap = sns.cubehelix_palette(light=1, dark = 0.1,
                             hue = 0.5, as_cmap=True)

sns.set_context(font_scale=2)

# Pair grid set up
g = sns.PairGrid(df)

# Scatter plot on the upper triangle
g.map_upper(plt.scatter, s=10, color = 'red')

# Distribution on the diagonal
g.map_diag(sns.distplot, kde=False, color = 'red')

# Density Plot and Correlation coefficients on the lower triangle
g.map_lower(sns.kdeplot, cmap = cmap)
g.map_lower(corrfunc);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kernels.py:128: RuntimeWarning: divide by zero encountered in true_divide
#   return (1. / np.sqrt(2 * np.pi)) * np.exp(-(Xi - x)**2 / (h**2 * 2.))
# /anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kernels.py:128: RuntimeWarning: invalid value encountered in true_divide
#   return (1. / np.sqrt(2 * np.pi)) * np.exp(-(Xi - x)**2 / (h**2 * 2.))
# /anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/_kernel_base.py:514: RuntimeWarning: invalid value encountered in true_divide
#   dens = Kval.prod(axis=1) / np.prod(bw[iscontinuous])
# /anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1533: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# /anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1534: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# /anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1176: RuntimeWarning: invalid value encountered in greater
#   inside = (self.levels > self.zmin) & (self.levels < self.zmax)
# /anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1176: RuntimeWarning: invalid value encountered in less
#   inside = (self.levels > self.zmin) & (self.levels < self.zmax)
# /anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1180: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
# 21. Create a Separate Feature Set (Data Matrix X) and Target (1D Vector y)

# It contains all attributes (all features and the target)
allData = df


y = df[' num_keywords'] # 1D targer vector
X = df.drop(columns=' num_keywords')  # Data Matrix containing all features excluding the target

allData.head()
# Out:
#       num_keywords   kw_avg_max   kw_min_avg    LDA_04   data_channel_is_tech  \
# 13             6.0     0.000000          0.0  0.033337                    0.0
# 47            10.0     0.000000          0.0  0.020005                    0.0
# 99             9.0  4055.555556          0.0  0.022226                    0.0
# 126           10.0  7269.000000          0.0  0.143039                    0.0
# 129           10.0  4110.000000          0.0  0.020000                    0.0
#
#       global_rate_negative_words    kw_max_avg
# 13                      0.052632      0.000000
# 47                      0.018634      0.000000
# 99                      0.005319   5428.571429
# 126                     0.011111  11800.000000
# 129                     0.007874   8566.666667

# %%
# 22. Create a Separate Test Set Data

from sklearn.model_selection import train_test_split


# Split into training/testing sets with 20% split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=42)

# %%
# 23. Establish Benchmarks

# Calculate mae and rmse
def evaluate_predictions(predictions, true):
    mae = np.mean(abs(predictions - true))
    rmse = np.sqrt(np.mean((predictions - true) ** 2))
    
    return mae, rmse

# %%
# 24. Naive Baseline

# Naive baseline is the median

import numpy as np


median_pred = y_train.median()

print(median_pred)



median_preds = [median_pred for _ in range(len(y_test))]
true = y_test


# Display the naive baseline metrics
mb_mae, mb_rmse = evaluate_predictions(median_preds, true)
print('Median Baseline  MAE: {:.4f}'.format(mb_mae))
print('Median Baseline RMSE: {:.4f}'.format(mb_rmse))
# Out:
# 7.0
# Median Baseline  MAE: 1.5005
# Median Baseline RMSE: 1.8463

# %%
# 25. Linear Regression Using Scikit-learn

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Create linear regression object
model = LinearRegression()

# Train the model using the traing data and label
model.fit(X_train, y_train)

# The intercept
b = model.intercept_
print('Intercept: \n',b )

# The feature weights (coefficients) in an array
m = model.coef_
print('Coefficients: \n', m)


# Show the prediction formula with the intercept and feature weight values
print("\nPrediction Formula: ")
print(' y(predicted) = {0} +  x_1 * {1} +  x_2 * {2} + x_3 * {3} + x_4 * {4} + x_5 * {5} + x_6 * {6}'
      .format(b, m[0], m[1], m[2], m[3], m[4], m[5]))


# Make predictions using the test data
y_predicted = model.predict(X_test)


# RMSE of the model
print("\nMean squared error: %.2f"
      % mean_squared_error(y_test, y_predicted))


# Explained variance score: 1 is perfect prediction
print('\nCoefficient of determination r^2 variance score [1 is perfect prediction]: %.2f' % r2_score(y_test, y_predicted))
# Out:
# Intercept:
#  8.16024687448
# Coefficients:
#  [ -2.65703273e-06  -3.04670766e-04   1.02265872e+00   2.11455334e-01
#   -8.19574727e+00   4.87302719e-05]
#
# Prediction Formula:
#  y(predicted) = 8.160246874484942 +  x_1 * -2.6570327314744625e-06 +  x_2 * -0.0003046707660355287 + x_3 * 1.022658718698699 + x_4 * 0.21145533437614317 + x_5 * -8.19574727131041 + x_6 * 4.873027189834608e-05
#
# Mean squared error: 2.89
#
# Coefficient of determination r^2 variance score [1 is perfect prediction]: 0.14

# %%
# Analysis of the Linear Regression Performance

import numpy as np

# Model Metrics
mae = np.mean(abs(y_predicted - y_test))
rmse = np.sqrt(np.mean((y_predicted - y_test) ** 2))

print("Linear Regression MAE: ", mae)
print("Linear Regression RMSE: ", rmse)


# Baseline Metrics
baseline = np.median(y_train)
baseline_mae = np.mean(abs(baseline - y_test))
baseline_rmse = np.sqrt(np.mean((baseline - y_test) ** 2))


print("\nBaseline MAE: ", baseline_mae)
print("Baseline RMSE: ", baseline_rmse)
# Out:
# Linear Regression MAE:  1.4262969109025563
# Linear Regression RMSE:  1.70026480723
#
# Baseline MAE:  1.5004868549172348
# Baseline RMSE:  1.84633640772
